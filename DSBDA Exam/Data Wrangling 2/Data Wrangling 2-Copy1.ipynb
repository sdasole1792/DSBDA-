# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/HP/Downloads/Book1.csv")

# %%
df
# Out:
#    Unnamed: 0     Id   Sub  Mark Result
# 0           1  101.0    WT  86.0   pass
# 1           2  102.0   DSA  50.0   pass
# 2           3  103.0    CC  80.0   pass
# 3           4  104.0    SE  46.0   pass
# 4           5  105.0  OOPS  90.0   pass
# 5           6  106.0    CG  35.0   fail
# 6           7  107.0    AI  24.0   fail
# 7           8    NaN   NaN   NaN    NaN
# 8           9    NaN   NaN   NaN    NaN
# 9          10    NaN   NaN   NaN    NaN

# %%
df.head()
# Out:
#    Unnamed: 0     Id   Sub  Mark Result
# 0           1  101.0    WT  86.0   pass
# 1           2  102.0   DSA  50.0   pass
# 2           3  103.0    CC  80.0   pass
# 3           4  104.0    SE  46.0   pass
# 4           5  105.0  OOPS  90.0   pass

# %%
df.tail()
# Out:
#    Unnamed: 0     Id  Sub  Mark Result
# 5           6  106.0   CG  35.0   fail
# 6           7  107.0   AI  24.0   fail
# 7           8    NaN  NaN   NaN    NaN
# 8           9    NaN  NaN   NaN    NaN
# 9          10    NaN  NaN   NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     int64
#  1   Id          7 non-null      float64
#  2   Sub         7 non-null      object
#  3   Mark        7 non-null      float64
#  4   Result      7 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 528.0+ bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Id            float64
# Sub            object
# Mark          float64
# Result         object
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0          Id       Mark
# count    10.00000    7.000000   7.000000
# mean      5.50000  104.000000  58.714286
# std       3.02765    2.160247  26.398954
# min       1.00000  101.000000  24.000000
# 25%       3.25000  102.500000  40.500000
# 50%       5.50000  104.000000  50.000000
# 75%       7.75000  105.500000  83.000000
# max      10.00000  107.000000  90.000000

# %%
df.Mark =df.Mark.astype("float")

# %%
df
# Out:
#    Unnamed: 0     Id   Sub  Mark Result
# 0           1  101.0    WT  86.0   pass
# 1           2  102.0   DSA  50.0   pass
# 2           3  103.0    CC  80.0   pass
# 3           4  104.0    SE  46.0   pass
# 4           5  105.0  OOPS  90.0   pass
# 5           6  106.0    CG  35.0   fail
# 6           7  107.0    AI  24.0   fail
# 7           8    NaN   NaN   NaN    NaN
# 8           9    NaN   NaN   NaN    NaN
# 9          10    NaN   NaN   NaN    NaN

# %%
m=pd.read_csv("C:/Users/HP/Downloads/Book1.csv")

# %%
m['Mark']=m['Mark'].fillna(df['Mark'].mean())

# %%
m
# Out:
#    Unnamed: 0     Id   Sub       Mark Result
# 0           1  101.0    WT  40.000000   pass
# 1           2  102.0   DSA  50.000000   pass
# 2           3  103.0    CC  60.000000   pass
# 3           4  104.0    SE  55.000000   pass
# 4           5  105.0  OOPS  99.000000   pass
# 5           6  106.0    CG  35.000000   fail
# 6           7  107.0    AI  42.000000   pass
# 7           8    NaN   NaN  58.714286    NaN
# 8           9    NaN   NaN  58.714286    NaN
# 9          10    NaN   NaN  58.714286    NaN

# %%
m.Mark =m.Mark.astype("int")

# %%
m
# Out:
#    Unnamed: 0     Id   Sub  Mark Result
# 0           1  101.0    WT    40   pass
# 1           2  102.0   DSA    50   pass
# 2           3  103.0    CC    60   pass
# 3           4  104.0    SE    55   pass
# 4           5  105.0  OOPS    99   pass
# 5           6  106.0    CG    35   fail
# 6           7  107.0    AI    42   pass
# 7           8    NaN   NaN    58    NaN
# 8           9    NaN   NaN    58    NaN
# 9          10    NaN   NaN    58    NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
m.boxplot()
# Out:
# <AxesSubplot:>

# %%
newdf=df[df["Mark"]<=60]
newdf
# Out:
#    Unnamed: 0     Id  Sub  Mark Result
# 1           2  102.0  DSA  50.0   pass
# 3           4  104.0   SE  46.0   pass
# 5           6  106.0   CG  35.0   fail
# 6           7  107.0   AI  24.0   fail

# %%
newdf.boxplot()
# Out:
# <AxesSubplot:>
